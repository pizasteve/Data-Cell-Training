# %%
import pandas as pd

url="https://datacell.netlify.app/"

df=pd.read_html(url)

data_dyalna = df[0]

# %%
data_dyalna
# Out:
#     Cell  First Name    Last name        Major                          Email  \
# 0    NaN         NaN          NaN          NaN                            NaN
# 1   DATA  Abdessamad        makan         DATA    abdessamadmakan26@gmail.com
# 2   DATA       Ammor      Khadija         DATA          kammor.1009@gmail.com
# 3   DATA      Mhamed      Majdoub         AMOA    mhamedmajdoub.ing@gmail.com
# 4   DATA      Aymane        Askri         DATA              1ayasgo@gmail.com
# 5   DATA    Elharran        Ayoub         DATA    elharranayoub2002@gmail.com
# 6   DATA        Noha  Benabdallah         DATA  nohatahabenabdellah@gmail.com
# 7   DATA      Brahim     Bentaleb         DATA          bbentaleb10@gmail.com
# 8   DATA        Reda       Chahmi  CLOUD & IOT          redachahmi0@GMAIL.com
# 9   DATA    Ghizlane        Ahlal         DATA       ghizlane.ahlal@ump.ac.ma
# 10  DATA     Oussama      Hamdani         DATA   oussamahamdani1718@gmail.com
# ...
